# %%
import pandas as pd

# %%
titanic_data = pd.read_csv("titanic.csv")

# %%
titanic_data.head(3)
# Out:
#    row.names pclass  survived                                 name   age  \
# 0          1    1st         1         Allen, Miss Elisabeth Walton  29.0
# 1          2    1st         0          Allison, Miss Helen Loraine   2.0
# 2          3    1st         0  Allison, Mr Hudson Joshua Creighton  30.0
#
#       embarked                        home.dest room      ticket   boat  \
# 0  Southampton                     St Louis, MO  B-5  24160 L221      2
# 1  Southampton  Montreal, PQ / Chesterville, ON  C26         NaN    NaN
# 2  Southampton  Montreal, PQ / Chesterville, ON  C26         NaN  (135)
#
#       sex
# 0  female
# 1  female
# 2    male

# %%
titanic_data.shape
# Out:
# (1313, 11)

# %%
titanic_data.dtypes
# Out:
# row.names      int64
# pclass        object
# survived       int64
# name          object
# age          float64
# embarked      object
# home.dest     object
# room          object
# ticket        object
# boat          object
# sex           object
# dtype: object

# %%
titanic_data.columns
# Out:
# Index(['row.names', 'pclass', 'survived', 'name', 'age', 'embarked',
#        'home.dest', 'room', 'ticket', 'boat', 'sex'],
#       dtype='object')

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 11 columns):
# row.names    1313 non-null int64
# pclass       1313 non-null object
# survived     1313 non-null int64
# name         1313 non-null object
# age          633 non-null float64
# embarked     821 non-null object
# home.dest    754 non-null object
# room         77 non-null object
# ticket       69 non-null object
# boat         347 non-null object
# sex          1313 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 112.9+ KB

# %%
titanic_data['survived'][0:5]
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: survived, dtype: int64

# %%
titanic_data[['survived','age','sex']][0:10]
# Out:
#    survived      age     sex
# 0         1  29.0000  female
# 1         0   2.0000  female
# 2         0  30.0000    male
# 3         0  25.0000  female
# 4         1   0.9167    male
# 5         1  47.0000    male
# 6         1  63.0000  female
# 7         0  39.0000    male
# 8         1  58.0000  female
# 9         0  71.0000    male

# %%
titanic_data['survived'].value_counts()
# Out:
# 0    864
# 1    449
# Name: survived, dtype: int64

# %%
pd.crosstab(titanic_data.sex, titanic_data.survived)
# Out:
# survived    0    1
# sex
# female    156  307
# male      708  142

# %%
below_five_years = titanic_data[titanic_data.age < 10]

# %%
below_five_years['survived'].value_counts(normalize = True ) * 100
# Out:
# 1    71.73913
# 0    28.26087
# Name: survived, dtype: float64

# %%
len(below_five_years)
# Out:
# 46

# %%
titanic_data.embarked.unique()
# Out:
# array(['Southampton', 'Cherbourg', nan, 'Queenstown'], dtype=object)

# %%
titanic_data.embarked.value_counts(dropna=False)
# Out:
# Southampton    573
# NaN            492
# Cherbourg      203
# Queenstown      45
# Name: embarked, dtype: int64

# %%
clean_titanic_data = titanic_data.dropna(axis = 1, how='any')

clean_titanic_data.shape
# Out:
# (1313, 5)

# %%
titanic_data.head(2)
# Out:
#    row.names pclass  survived                          name   age  \
# 0          1    1st         1  Allen, Miss Elisabeth Walton  29.0
# 1          2    1st         0   Allison, Miss Helen Loraine   2.0
#
#       embarked                        home.dest room      ticket boat     sex
# 0  Southampton                     St Louis, MO  B-5  24160 L221    2  female
# 1  Southampton  Montreal, PQ / Chesterville, ON  C26         NaN  NaN  female

# %%
 titanic_data.rename(columns = {'row.names':'row_number'}, inplace = True)

# %%
titanic_data.iloc[0:10,0:10]
# Out:
#    row_number pclass  survived  \
# 0           1    1st         1
# 1           2    1st         0
# 2           3    1st         0
# 3           4    1st         0
# 4           5    1st         1
# 5           6    1st         1
# 6           7    1st         1
# 7           8    1st         0
# 8           9    1st         1
# 9          10    1st         0
#
#                                               name      age     embarked  \
# 0                     Allen, Miss Elisabeth Walton  29.0000  Southampton
# 1                      Allison, Miss Helen Loraine   2.0000  Southampton
# 2              Allison, Mr Hudson Joshua Creighton  30.0000  Southampton
# 3  Allison, Mrs Hudson J.C. (Bessie Waldo Daniels)  25.0000  Southampton
# 4                    Allison, Master Hudson Trevor   0.9167  Southampton
# 5                               Anderson, Mr Harry  47.0000  Southampton
# 6                 Andrews, Miss Kornelia Theodosia  63.0000  Southampton
# ...

# %%
titanic_data["gender"] = titanic_data.sex.map(lambda x: int(x == 'male'))

titanic_data.head(10)
# Out:
#    row_number pclass  survived  \
# 0           1    1st         1
# 1           2    1st         0
# 2           3    1st         0
# 3           4    1st         0
# 4           5    1st         1
# 5           6    1st         1
# 6           7    1st         1
# 7           8    1st         0
# 8           9    1st         1
# 9          10    1st         0
#
#                                               name      age     embarked  \
# 0                     Allen, Miss Elisabeth Walton  29.0000  Southampton
# 1                      Allison, Miss Helen Loraine   2.0000  Southampton
# 2              Allison, Mr Hudson Joshua Creighton  30.0000  Southampton
# 3  Allison, Mrs Hudson J.C. (Bessie Waldo Daniels)  25.0000  Southampton
# 4                    Allison, Master Hudson Trevor   0.9167  Southampton
# 5                               Anderson, Mr Harry  47.0000  Southampton
# 6                 Andrews, Miss Kornelia Theodosia  63.0000  Southampton
# ...

# %%
titanic_data.groupby('pclass')['age'].mean()
# Out:
# pclass
# 1st    39.667773
# 2nd    28.300314
# 3rd    24.519658
# Name: age, dtype: float64

# %%
titanic_data[(titanic_data.survived == 1)][0:10]
# Out:
#     row_number pclass  survived  \
# 0            1    1st         1
# 4            5    1st         1
# 5            6    1st         1
# 6            7    1st         1
# 8            9    1st         1
# 11          12    1st         1
# 12          13    1st         1
# 13          14    1st         1
# 15          16    1st         1
# 18          19    1st         1
#
#                                                 name      age     embarked  \
# 0                       Allen, Miss Elisabeth Walton  29.0000  Southampton
# 4                      Allison, Master Hudson Trevor   0.9167  Southampton
# 5                                 Anderson, Mr Harry  47.0000  Southampton
# 6                   Andrews, Miss Kornelia Theodosia  63.0000  Southampton
# 8       Appleton, Mrs Edward Dale (Charlotte Lamson)  58.0000  Southampton
# 11  Astor, Mrs John Jacob (Madeleine Talmadge Force)  19.0000    Cherbourg
# 12                      Aubert, Mrs Leontine Pauline      NaN    Cherbourg
# ...
